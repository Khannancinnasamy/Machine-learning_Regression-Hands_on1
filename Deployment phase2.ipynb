# %%
# Deployment for MLR
import pickle

# %%
loaded_model = pickle.load(open("Finalized_model_mul_linear.sav", 'rb'))
result = loaded_model.predict([[2344,345,435,0,1]])
# Out:
# C:\Users\Kannan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[44586.30936555]])

# %%
loaded_model = pickle.load(open("Finalized_model_mul_linear.sav", 'rb'))
result = loaded_model.predict([[3214, 5123, 2, 4, 1234]])
# Out:
# C:\Users\Kannan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[423075.18134815]])
